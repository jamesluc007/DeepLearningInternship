# %%
from osgeo import gdal, gdalnumeric, ogr, osr
from PIL import Image, ImageDraw
import sys, os
from osgeo import gdal_array
import numpy as np
import matplotlib.pyplot as plt

# %%
#ACCEDO A LAS IMÁGENES SATELITALES correspondientes

b1 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band1.tif"
b2 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band2.tif"
b3 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band3.tif"
b4 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band4.tif"
b5 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band5.tif"
b6 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band6.tif"
b7 = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band7.tif"

band1 = gdal.Open(b1, gdal.GA_ReadOnly)
band2 = gdal.Open(b2, gdal.GA_ReadOnly)
band3 = gdal.Open(b3, gdal.GA_ReadOnly)
band4 = gdal.Open(b4, gdal.GA_ReadOnly)
band5 = gdal.Open(b5, gdal.GA_ReadOnly)
band6 = gdal.Open(b6, gdal.GA_ReadOnly)
band7 = gdal.Open(b7, gdal.GA_ReadOnly)

# %%
#JUNTO A LAS BANDAS 4,3 Y 2 QUE SEGÚN wikipedia SON LAS BANDAS ROJA, VERDE Y AZUL RESPECTIVAMENTE
#De esa manera, formo una imágen visualizable RGB
#Esta servirá más adelante como verificación en la generación de un Dataset

red_array = band4.ReadAsArray()
green_array = band3.ReadAsArray()
blue_array = band2.ReadAsArray()

imagen = (np.zeros(red_array.size*3, dtype = 'int16')).reshape(red_array.shape[0],red_array.shape[1],3)

imagen[:,:,0] = red_array
imagen[:,:,1] = blue_array
imagen[:,:,2] = green_array

# %%
red_array = band4.ReadAsArray().astype(np.float32)
green_array = band3.ReadAsArray().astype(np.float32)
blue_array = band2.ReadAsArray().astype(np.float32)

imagen = (np.zeros(red_array.size*3, dtype = np.float32)).reshape(red_array.shape[0],red_array.shape[1],3)

imagen[:,:,0] = red_array
imagen[:,:,1] = blue_array
imagen[:,:,2] = green_array

# %%
#imagen.dtype
# Out:
# dtype('float32')

# %%
import geoio
filename = r"E:\Imágenes Satelitales\2017\226_86\1\LC08_L1TP_226086_20170116_20170311_01_T1_sr_band3.tif"
#img = geoio.GeoImage(filename)
lon = -61.14937
lat = -37.76056
#xPixel, yPixel = img.proj_to_raster(lon,lat)

# %%
# Getting spatial reference of input raster
#srs = osr.SpatialReference()
#srs.ImportFromWkt(projection)

# WGS84 projection reference
#OSR_WGS84_REF = osr.SpatialReference()
#OSR_WGS84_REF.ImportFromEPSG(4326)

# OSR transformation
#wgs84_to_image_trasformation = osr.CoordinateTransformation(OSR_WGS84_REF, srs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-041edc721fd9> in <module>
#      12 wkt_geom = 'ST_GeomFromText( LINESTRING( -61.14937 , -37.76056),4326)'
#      13
# ---> 14 wkt_geom.Transform(wgs84_to_image_trasformation)
#
# AttributeError: 'str' object has no attribute 'Transform'

# %%
#point = ogr.Geometry(ogr.wkbPoint)
#point.AddPoint(lon, lat)
#point.ExportToWkt()
# Out:
# 'POINT (-61.14937 -37.76056 0)'

# %%
#Esto me puede servir para pasar de lon lat en el sistema WGS84 a los pixeles correspondientes de la imagen

# https://pcjericks.github.io/py-gdalogr-cookbook/projection.html

#from osgeo import ogr
#from osgeo import osr

#source = osr.SpatialReference()
#source.ImportFromEPSG(2927)

#target = osr.SpatialReference()
#target.ImportFromEPSG(4326)

#transform = osr.CoordinateTransformation(source, target)

#point = ogr.CreateGeometryFromWkt("POINT (1120351.57 741921.42)")
#point.Transform(transform)

#print point.ExportToWkt()

# %%
from osgeo import ogr
from osgeo import osr

# %%
source = osr.SpatialReference()
source.ImportFromEPSG(4326)
target = osr.SpatialReference()

# %%
target.SetProjection(band1.GetProjection)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-9e6515c93859> in <module>
# ----> 1 target.SetProjection(band1.GetProjection)
#
# D:\Programas\AnacondaFinal\lib\site-packages\osgeo\osr.py in SetProjection(self, *args)
#     816     def SetProjection(self, *args):
#     817         """SetProjection(SpatialReference self, char const * arg) -> OGRErr"""
# --> 818         return _osr.SpatialReference_SetProjection(self, *args)
#     819
#     820
#
# TypeError: in method 'SpatialReference_SetProjection', argument 2 of type 'char const *'

# %%
#GRAFICO LA IMÁGEN EN RGB
#Aquí en Jupyter no se aprecia muy bien pero la imagen la guardo como 'rgb.png', se puede abrir con un visor de imágenes
#y así apreciar bien. Incluso abrirla desde el QGIS para verificar que es correcto lo que se está graficando

plt.imshow((imagen).astype(np.uint8),cmap='RdYlGn')
plt.plot(xPixel,yPixel,'o')
plt.savefig('rgb.png', dpi=1250)
#plt.plot()

# %%
#GRAFICO SOLO EL CANAL ROJO, es para verificacion
#Nuevamente guardo la imagen como png para verla mejor

plt.imshow(red_array, cmap = 'hot')
plt.plot()
plt.savefig('red_band.png', dpi=500)
#plt.hist(red_array.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k')
